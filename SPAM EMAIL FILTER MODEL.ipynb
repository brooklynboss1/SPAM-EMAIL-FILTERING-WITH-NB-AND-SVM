# %% [markdown]
# # Download Data

# %%
import os

directory = r"C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data"

# Check if the directory already exists
if not os.path.exists(directory):
    try:
        # Create the directory if it doesn't exist
        os.makedirs(directory)
        print(f"Created directory: {directory}")
    except OSError as e:
        # Handle any error that occurs while creating the directory
        print(f"Failed to create directory: {directory}")
        print(f"Error: {str(e)}")
else:
    print(f"Directory already exists: {directory}")
# Out:
# Directory already exists: C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data

# %%
import os

directory = r'C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data'

# List the files and directories within the 'data' directory
contents = os.listdir(directory)

for item in contents:
    item_path = os.path.join(directory, item)
    if os.path.isdir(item_path):
        print(f"Directory: {item}")
    else:
        print(f"File: {item}")

import os
import urllib.request
import shutil

local_path = r"C:\Users\BROOKLYNBOSS\Desktop\PROJECT"
destination_dir = r"C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data"

# Ensure destination directory exists
os.makedirs(destination_dir, exist_ok=True)

source_files = [
    os.path.join(local_path, "20030228_easy_ham.tar.bz2"),
    os.path.join(local_path, "20030228_easy_ham_2.tar.bz2"),
    os.path.join(local_path, "20030228_hard_ham.tar.bz2"),
    os.path.join(local_path, "20030228_spam.tar.bz2"),
    os.path.join(local_path, "20050311_spam_2.tar.bz2")
]

# Counter for successfully copied files
success_count = 0

# Copy files from the local directory or download from the web
for source_file in source_files:
    filename = os.path.basename(source_file)
    local_file_path = os.path.join(local_path, filename)
    destination_file_path = os.path.join(destination_dir, filename)

    if os.path.exists(local_file_path):
        print(f"File '{filename}' found in the local directory. Copying...")
        shutil.copy(local_file_path, destination_file_path)
        print(f"File '{filename}' copied to the destination directory.")
        success_count += 1
    else:
        print(f"File '{filename}' not found in the local directory. Downloading...")
        url = f"https://spamassassin.apache.org/old/publiccorpus/{filename}"
        urllib.request.urlretrieve(url, destination_file_path)
        print(f"File '{filename}' downloaded successfully.")
        success_count += 1

print(f"{success_count} files were successfully copied.")
# Out:
# Directory: spam data
# File '20030228_easy_ham.tar.bz2' found in the local directory. Copying...
# File '20030228_easy_ham.tar.bz2' copied to the destination directory.
# File '20030228_easy_ham_2.tar.bz2' found in the local directory. Copying...
# File '20030228_easy_ham_2.tar.bz2' copied to the destination directory.
# File '20030228_hard_ham.tar.bz2' found in the local directory. Copying...
# File '20030228_hard_ham.tar.bz2' copied to the destination directory.
# File '20030228_spam.tar.bz2' found in the local directory. Copying...
# File '20030228_spam.tar.bz2' copied to the destination directory.
# File '20050311_spam_2.tar.bz2' found in the local directory. Copying...
# File '20050311_spam_2.tar.bz2' copied to the destination directory.
# 5 files were successfully copied.

# %%
# file extraction
import os
import tarfile

directory = r"C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data"
archive_files = [
    "20030228_easy_ham_2.tar.bz2",
    "20030228_easy_ham.tar.bz2",
    "20030228_hard_ham.tar.bz2",
    "20030228_spam.tar.bz2",
    "20050311_spam_2.tar.bz2"
]

# Extract files from each archive
for archive_file in archive_files:
    archive_path = os.path.join(directory, archive_file)
    print(f"Extracting {archive_file}...")
    with tarfile.open(archive_path, "r:bz2") as tar:
        tar.extractall(directory)
    print(f"Extraction of {archive_file} complete.")

print("All archives extracted.")
# Out:
# Extracting 20030228_easy_ham_2.tar.bz2...
# Extraction of 20030228_easy_ham_2.tar.bz2 complete.
# Extracting 20030228_easy_ham.tar.bz2...
# Extraction of 20030228_easy_ham.tar.bz2 complete.
# Extracting 20030228_hard_ham.tar.bz2...
# Extraction of 20030228_hard_ham.tar.bz2 complete.
# Extracting 20030228_spam.tar.bz2...
# Extraction of 20030228_spam.tar.bz2 complete.
# Extracting 20050311_spam_2.tar.bz2...
# Extraction of 20050311_spam_2.tar.bz2 complete.
# All archives extracted.

# %% [markdown]
# # Start Coding

# %%
# %matplotlib inline
import os
import glob
import numpy as np
import email

# %%
path = r"C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data"
print(path)
# Out:
# C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data

# %%
easy_ham_paths = os.path.join(path, 'easy_ham')
easy_ham_2_paths = os.path.join(path, 'easy_ham_2')
hard_ham_paths = os.path.join(path, 'hard_ham')
spam_paths = os.path.join(path, 'spam')
spam_2_paths = os.path.join(path, 'spam_2')

print(easy_ham_paths)
print(easy_ham_2_paths)
print(hard_ham_paths)
print(spam_paths)
print(spam_2_paths)
# Out:
# C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\easy_ham
# C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\easy_ham_2
# C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\hard_ham
# C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\spam
# C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\spam_2

# %%
def get_email_content(email_path):
    with open(email_path, encoding='latin1') as file:
        try:
            msg = email.message_from_file(file)
            for part in msg.walk():
                if part.get_content_type() == 'text/plain':
                    return part.get_payload()  # prints the raw text
        except Exception as e:
            print(e)

def get_email_content_bulk(email_paths):
    email_contents = [get_email_content(o) for o in email_paths]
    return email_contents

# %% [markdown]
# # Split data into train/test

# %%
from sklearn.model_selection import train_test_split

# %%
ham_path = [
    easy_ham_paths,
    easy_ham_2_paths,
    hard_ham_paths
]

spam_path = [
    spam_paths,
    spam_2_paths
]
print(ham_path)
print(spam_path)
# Out:
# ['C:\\Users\\BROOKLYNBOSS\\Desktop\\PROJECT\\data\\spam data\\easy_ham', 'C:\\Users\\BROOKLYNBOSS\\Desktop\\PROJECT\\data\\spam data\\easy_ham_2', 'C:\\Users\\BROOKLYNBOSS\\Desktop\\PROJECT\\data\\spam data\\hard_ham']
# ['C:\\Users\\BROOKLYNBOSS\\Desktop\\PROJECT\\data\\spam data\\spam', 'C:\\Users\\BROOKLYNBOSS\\Desktop\\PROJECT\\data\\spam data\\spam_2']

# %%
for path in ham_path:
    files = os.listdir(path)
    for filename in files:
        if not filename.endswith('.txt'):
            new_filename = os.path.splitext(filename)[0] + '.txt'
            
            # Check if the .txt file already exists in the directory
            if os.path.exists(os.path.join(path, new_filename)):
                print(f"Skipped: {filename} (already has .txt extension)")
            else:
                os.rename(os.path.join(path, filename), os.path.join(path, new_filename))
                print(f"Renamed: {filename} -> {new_filename}")
# Out:
# Skipped: 00001.7c53336b37003a9286aba55d2945844c (already has .txt extension)
# Skipped: 00002.9c4069e25e1ef370c078db7ee85ff9ac (already has .txt extension)
# Skipped: 00003.860e3c3cee1b42ead714c5c874fe25f7 (already has .txt extension)
# Skipped: 00004.864220c5b6930b209cc287c361c99af1 (already has .txt extension)
# Skipped: 00005.bf27cdeaf0b8c4647ecd61b1d09da613 (already has .txt extension)
# Skipped: 00006.253ea2f9a9cc36fa0b1129b04b806608 (already has .txt extension)
# Skipped: 00118.f15bf997342540b404a4672c47d57d55 (already has .txt extension)
# Skipped: 00119.0f469afee6aef0a05d9850f7021bd629 (already has .txt extension)
# Skipped: 00120.4de6f88fbcb22a39a0498f84d9ce358b (already has .txt extension)
# Skipped: 00121.333fff2f2cb3dfd617a6210b669757d3 (already has .txt extension)
# Skipped: 00122.b4b9733750e203d0215d49043d29c173 (already has .txt extension)
# Skipped: 00123.91b85aaea560d92f9199f9ba74e77918 (already has .txt extension)
# Skipped: 00124.f0f8fe0588f5245c08846ca9d308dfb1 (already has .txt extension)
# Skipped: 00125.0b972a986a586ab4ba3ff45e88f330db (already has .txt extension)
# Skipped: 00126.b0a45fbc9d8f9e6de6be5d3062cc91ef (already has .txt extension)
# Skipped: 00127.c1981aeb12ebd22536f12f0a044efe56 (already has .txt extension)
# Skipped: 00128.0e92ec0c8bd8233f7e7873e93df43277 (already has .txt extension)
# Skipped: 00129.ac1318f7fba969847e1ac4aa4ec3c26a (already has .txt extension)
# Skipped: 00130.77c75ddeffde2b89edaf8720370f6afc (already has .txt extension)
# Skipped: 00131.0884e29887b7378ca04f4defe0a069e0 (already has .txt extension)
# Skipped: 00132.2eddfbbe44385a450eae4ee89da0a830 (already has .txt extension)
# Skipped: 00133.e5aa9fa1cc35faff5801a6b16ca7afa6 (already has .txt extension)
# Skipped: 00134.f7d26b0dc6c2f3de63b08d2810d54df6 (already has .txt extension)
# Skipped: 00135.bd3bc1c036eab89c9c50cff40958c939 (already has .txt extension)
# Skipped: 00136.c507301e643ec123aa6e487ce2e2e3e2 (already has .txt extension)
# Skipped: 00137.11311a8e5dbfe18503bf736b82b91fc7 (already has .txt extension)
# Skipped: 00138.b4fe49f8cd3b3bcc8d19741e705b0e01 (already has .txt extension)
# Skipped: 00139.cfea5d726c0371fa63c9720a291ca9ad (already has .txt extension)
# Skipped: 00140.354632516317e3a37a05e93c609ec65d (already has .txt extension)
# Skipped: 00141.00b956daf6951da2bea354300d121512 (already has .txt extension)
# Skipped: 00142.0f7dc427ea4ecdf0c257b8bf7d152249 (already has .txt extension)
# Skipped: 00143.4cae4623140fc349a57dac7ffd863227 (already has .txt extension)
# Skipped: 00144.a6f12b97adc08a63ce541daaba0b0825 (already has .txt extension)
# Skipped: 00145.9e4594abeb96d3ba5650b9cf88e91015 (already has .txt extension)
# Skipped: 00146.a6d4ba98c7866de55109077d2960d245 (already has .txt extension)
# Skipped: 00147.fcb1b60290a155a5b837cd290b77a6dd (already has .txt extension)
# Skipped: 00148.6bdcd2791992fb3b923e961f71295ce8 (already has .txt extension)
# Skipped: 00149.6ace09f27948721429b08699d9b92f4c (already has .txt extension)
# Skipped: 00150.a4c5a8aaccd6b54f1000e9fa02f53114 (already has .txt extension)
# Skipped: 00151.4ecb35a7f837a0240663d3bbc5c8dbe8 (already has .txt extension)
# Skipped: 00152.703c271de3d42fb8bf266db6f77a0dda (already has .txt extension)
# Skipped: 00153.2ba33aef8f6b3010c92db7f992fbec43 (already has .txt extension)
# Skipped: 00154.cc63335f9a4e3b5f4a16be338b0d00a4 (already has .txt extension)
# Skipped: 00340.91d8c92aa5eccc84c40364fc4fc1ed63 (already has .txt extension)
# Skipped: 00341.c7f56e7cd829d52190cfd4af810bebce (already has .txt extension)
# Skipped: 00342.e6c781df2ebba44a429b49b86b376559 (already has .txt extension)
# Skipped: 00343.81675074f7fcb53fd83ebabd4d158cb7 (already has .txt extension)
# Skipped: 00344.99ffe210a9d425a86ab01840bdfd86c9 (already has .txt extension)
# Skipped: 00345.20c35f26ff6b56d678fdbe7750477668 (already has .txt extension)
# Skipped: 00346.f1d941485f6a20b29329111c59760585 (already has .txt extension)
# Skipped: 00347.f133df7e59af41ba1c596e60dde9dc48 (already has .txt extension)
# Skipped: 00348.009168209d00ae1cb41ebe3a7f113d4b (already has .txt extension)
# Skipped: 00349.0a6507ca70c84e4beab8698a733970f6 (already has .txt extension)
# Skipped: 00350.b01dafc878fcedbeee6a4d7c120ef0c4 (already has .txt extension)
# Skipped: 00351.edc235781cd0e2e3b562d868d3a8df62 (already has .txt extension)
# Skipped: 00352.986723b3325cd57e893cfcdf992d59b3 (already has .txt extension)
# Skipped: 00353.ec01b62420323fffe253643fe0439c86 (already has .txt extension)
# Skipped: 00354.2302c4c1801e52a59346a64a5a31ed85 (already has .txt extension)
# Skipped: 00355.9fabc0fb3da1d8376c6db0702b60fb39 (already has .txt extension)
# Skipped: 00356.f414aefc1fc74d9cd77da0f07f64546c (already has .txt extension)
# Skipped: 00357.d559b71616f64ba1d1c1e61a03644fd4 (already has .txt extension)
# Skipped: 00358.df37619f4cc3d224acd6f8e57e67fd24 (already has .txt extension)
# Skipped: 00359.dad4917f824800d6623db29ea557b514 (already has .txt extension)
# Skipped: 00360.5e45677c7b7a664d516da6b003d9656d (already has .txt extension)
# Skipped: 00361.6a215262fed7b15f657b22c65107eafd (already has .txt extension)
# Skipped: 00362.bfb007d2df523d5e4ad58dfcdbc1b8cb (already has .txt extension)
# Skipped: 00363.64af27f0c753ccf6ec2e9c4e64c14b76 (already has .txt extension)
# Skipped: 00364.30f174421507d353f1f602919dec35af (already has .txt extension)
# Skipped: 00365.b73623c2ea40e64854121432f02a5a15 (already has .txt extension)
# Skipped: 00366.e6bc462793d21f588e2368dc089399fc (already has .txt extension)
# Skipped: 00367.d44ba629ed6383ee94999179bb6a04e2 (already has .txt extension)
# Skipped: 00368.f86324a03e7ae7070cc40f302385f5d3 (already has .txt extension)
# Skipped: 00369.f6f9d4cac4af831140abf032d0378365 (already has .txt extension)
# Skipped: 00370.0a2e3b397565840b5c4e46d5c5700444 (already has .txt extension)
# Skipped: 00371.3d08a5b828fb31bdacd4d07cad065171 (already has .txt extension)
# Skipped: 00372.caa02bf9e0bbd7643dbe83fbac984003 (already has .txt extension)
# Skipped: 00373.818730ce90950ecbf244e045a713de53 (already has .txt extension)
# Skipped: 00374.67d51286926b6af9ae9be32a9e446b29 (already has .txt extension)
# Skipped: 00375.205477cf488dba15ec6dbc46011b8251 (already has .txt extension)
# Skipped: 00376.3d17aeac1de8eee4383e077b9e0fe703 (already has .txt extension)
# Skipped: 00526.27d0075c192b704fd3b804497b8c33d1 (already has .txt extension)
# Skipped: 00527.fe739430917f1facd61acbc162d71970 (already has .txt extension)
# Skipped: 00528.4069e359640cbe831b602fd3cc387469 (already has .txt extension)
# Skipped: 00529.f267247f996b2eab55c6e18b63e3968b (already has .txt extension)
# Skipped: 00530.1a07bbd6fe2438ed2b3f11e92449327c (already has .txt extension)
# Skipped: 00531.711a16c97d6955bdc3d4b09656e44d93 (already has .txt extension)
# Skipped: 00532.81180d4d1d632bb50c189b51f83921e0 (already has .txt extension)
# Skipped: 00533.ebdd2ab43a73a867388b595061d66d59 (already has .txt extension)
# Skipped: 00534.6db349fcd98d25f61e5bcc4552b45f57 (already has .txt extension)
# Skipped: 00535.2c21f614f9593edc5049248d6e873ce8 (already has .txt extension)
# Skipped: 00536.ee0a85c68f0db6388d6f8a3468af70ac (already has .txt extension)
# Skipped: 00537.0b676300c214afdc2dd6a5007e8b8e2a (already has .txt extension)
# Skipped: 00538.313057481a3b1638c05066fad46ae65f (already has .txt extension)
# Skipped: 00539.f3a3a009e8410ed004b045e724be525a (already has .txt extension)
# Skipped: 00540.c9e660864381381e6a16c599c8f2e1fe (already has .txt extension)
# Skipped: 00541.cbdcefd1a6109b8f95e1c8dddfbd7bb2 (already has .txt extension)
# Skipped: 00542.1db9cca8020648c0ed80436b9aea4d33 (already has .txt extension)
# Skipped: 00543.0641e755767b41b404070e155708cee6 (already has .txt extension)
# Skipped: 00544.5a9365cf80100b89b50656045cb8b80c (already has .txt extension)
# Skipped: 00545.99996f28814c7028ce6aac44270ff3cd (already has .txt extension)
# Skipped: 00546.30fed3b8e986dc41b1865b9285e84e56 (already has .txt extension)
# Skipped: 00547.59bf01e07cf08c7e3a778b747e020989 (already has .txt extension)
# Skipped: 00548.120e45c5d33311bc09e844bf236521d2 (already has .txt extension)
# Skipped: 00549.a847ea8934802a0ec67a7fd1d136d26d (already has .txt extension)
# Skipped: 00550.02e6c81fb637ae555b997d6fd72df731 (already has .txt extension)
# Skipped: 00551.1c59fd8e4f3176c859b79b9a75fcc3b6 (already has .txt extension)
# Skipped: 00552.2a17c933697e682b93c2f32b66230a3b (already has .txt extension)
# Skipped: 00553.d1e0ab732c8cbe70432e98301e352954 (already has .txt extension)
# Skipped: 00554.a01a74aee9653a7ae8d1d558c75f0a5d (already has .txt extension)
# Skipped: 00555.4139b207075574b3774942a3a42013d8 (already has .txt extension)
# Skipped: 00556.eea9a26e128c1b4b676b4180adbd547a (already has .txt extension)
# Skipped: 00557.62ed7b82fd342ca4d7932ccee2552337 (already has .txt extension)
# Skipped: 00558.95b8c2677759a2f569a5dc0bd70b8cc0 (already has .txt extension)
# Skipped: 00559.caa975fbe7e1641a76de679bdf213adc (already has .txt extension)
# Skipped: 00560.e49654efbb65ad7539d43d356457a322 (already has .txt extension)
# Skipped: 00561.4fb75fe802e36488a6acbbcccbcde3c1 (already has .txt extension)
# Skipped: 00562.3f2a351171504facae22864c794c26b6 (already has .txt extension)
# Skipped: 00563.8c8efdf5034a0ba771e48494fd2d8099 (already has .txt extension)
# Skipped: 00564.e6fc359c277f507a2e01198b9c60ae61 (already has .txt extension)
# Skipped: 00565.4ef76da45577ee17827cec345ac543b0 (already has .txt extension)
# Skipped: 00566.4ce66e249726f98555ef3a7ba1f666d5 (already has .txt extension)
# Skipped: 00567.aa0b1a5ccd63ce58ca09389b7dd7a5aa (already has .txt extension)
# Skipped: 00568.e5478bfa670cbd9bc3d26ed23e7b3eb6 (already has .txt extension)
# Skipped: 00569.d6da87140fd0ef187bcf217a57153cca (already has .txt extension)
# Skipped: 00570.d98ca90ac201b5d881f2397c95838eb2 (already has .txt extension)
# Skipped: 00571.8f35c46bee6d7a238eabf207a5696b0c (already has .txt extension)
# Skipped: 00572.c406ac5bc5c42bedbce48f5661d29976 (already has .txt extension)
# Skipped: 00573.f36b8bb4af93f6b0736e7475eb6cbcba (already has .txt extension)
# Skipped: 00574.6c736036ab8317e753dae53ef19123e9 (already has .txt extension)
# Skipped: 00575.c4b32c1dc29245ce6298f5abf2f0b085 (already has .txt extension)
# Skipped: 00576.36892439c0a6bdd5b4231b639b639399 (already has .txt extension)
# Skipped: 00577.8f3db8ab8b69d38bddf8e5a91b353da2 (already has .txt extension)
# Skipped: 00578.8c710aa944374d631b9969a806e32a30 (already has .txt extension)
# Skipped: 00579.566d8e05220571bff1c2f392a1c7bf41 (already has .txt extension)
# Skipped: 00580.41f4f9793351fe7c7d3abe77cedc5528 (already has .txt extension)
# Skipped: 00581.9922b0f34aa8f51fb4adf4bf4ecf1464 (already has .txt extension)
# Skipped: 00582.25153a03da1710fd133d6ff373d612d3 (already has .txt extension)
# Skipped: 00583.7db5166f3ec5a8bcf81bf1b639b48361 (already has .txt extension)
# Skipped: 00584.1994033689471c5000d715aeaaf7be24 (already has .txt extension)
# Skipped: 00585.a55a40c5fca535871d78848d27efd540 (already has .txt extension)
# Skipped: 00586.7ca83d6acc8e5b0e44b78a4fe8bab72c (already has .txt extension)
# Skipped: 00587.8d78332c747a44bf017724d66bf71647 (already has .txt extension)
# Skipped: 00588.708ecb20113d4c80b91936cd1c86b186 (already has .txt extension)
# Skipped: 00589.38f809ae603fbabb0d3f2389011e9150 (already has .txt extension)
# Skipped: 00590.3b596d6b2e6ad9b9f5cf3593a398260b (already has .txt extension)
# Skipped: 00591.3bca4fff29ae5e89e2e2948401a24ab8 (already has .txt extension)
# Skipped: 00592.9608ca87c212f35feae1ebde5567c0e2 (already has .txt extension)
# Skipped: 00593.f71a708b88b51c4d428bb3bd741ece2d (already has .txt extension)
# Skipped: 00594.805dae98d1ad6f99a7792418c1faccfd (already has .txt extension)
# Skipped: 00595.7182665eb052808e2061bacbc75ed5ee (already has .txt extension)
# Skipped: 00596.73c2473a9c778e096f3a9160d72567e9 (already has .txt extension)
# Skipped: 00597.d69fd43248612845c272cc277b890e1a (already has .txt extension)
# Skipped: 00598.583ed313ddee00f0dc9929f76d3bb24e (already has .txt extension)
# Skipped: 00599.94c013ab7037d45045aafbac3389bef0 (already has .txt extension)
# Skipped: 00095.8649aca72a33fe998c9b95ad00dc4d7f (already has .txt extension)
# Skipped: 00096.bfde9cb2286020360aea7e6e5dcbb39e (already has .txt extension)
# Skipped: 00097.90200a177414673b08df827239a0b9dc (already has .txt extension)
# Skipped: 00098.1dcbcaac22d03392c7bcfb4e86bc3c39 (already has .txt extension)
# Skipped: 00099.83f69964f7132d2c244a3374b94c285e (already has .txt extension)
# Skipped: 00100.78af3dc4c39277a6e1893f287cc2771f (already has .txt extension)
# Skipped: 00101.35e2f90cbe45708b1c1dcb606b554ca7 (already has .txt extension)
# Skipped: 00102.10533c2a8486368eea6acd0d07549f3b (already has .txt extension)
# Skipped: 00103.3c2ed4232a349875b6ba4d78a9a7eb08 (already has .txt extension)
# Skipped: 00104.75eda98a9139049e191d3cfa09860c9d (already has .txt extension)
# Skipped: 00105.e036059691d419bf35813576e85aecce (already has .txt extension)
# Skipped: 00106.8325a1afdd64c2945889fc4b0e80d363 (already has .txt extension)
# Skipped: 00107.88cccf3d99a841ce92bdff029e137ed9 (already has .txt extension)
# Skipped: 00108.c616dad1b875643b5f48452beadf54b0 (already has .txt extension)
# Skipped: 00109.869c6cf86d562eed3692f760e9320cc0 (already has .txt extension)
# Skipped: 00110.77ac47048cafa2fe2587182f6d6b19d2 (already has .txt extension)
# Skipped: 00111.9b8da30db6709b590398fe8923a7180c (already has .txt extension)
# Skipped: 00112.3851987ee7827b01ddb89bb99999adc4 (already has .txt extension)
# Skipped: 00113.1d37bdbcad4975b5012cc6d87a048ecf (already has .txt extension)
# Skipped: 00114.b9a6a48a7c95e5d57507e4f8de05c8de (already has .txt extension)
# Skipped: 00115.951fbc0e7de3d8ae828928279e43175c (already has .txt extension)
# Skipped: 00116.28d07fa9ce0ad698cf6d7ccf1cb7e605 (already has .txt extension)
# Skipped: 00117.cf6312eae6441d25bef2ecfc39cc4acb (already has .txt extension)
# Skipped: 00118.afcf98c4f10a53e86d033ddf95660b5d (already has .txt extension)
# Skipped: 00119.4cb9c1c20358b4c2a6df2cdc5670fe62 (already has .txt extension)
# Skipped: 00120.4614aadda75cb2e069a6c22cabc5aea0 (already has .txt extension)
# Skipped: 00121.92d8827f2a5d552697f3bd261e6c0399 (already has .txt extension)
# Skipped: 00122.c0299a711b7392c9e93da37cce2fdc90 (already has .txt extension)
# Skipped: 00123.d9456f172d3424987c46cb49b7b6b012 (already has .txt extension)
# Skipped: 00124.ac778f6679d31ae64aae6fdb88327fbb (already has .txt extension)
# Skipped: 00125.ae44df3c54c4ab59e4b0f1f63550f582 (already has .txt extension)
# Skipped: 00126.4b3874844ccb78cd7ca2cd03876124b0 (already has .txt extension)
# Skipped: 00127.ab907b37736fd663c0db15b5575cc416 (already has .txt extension)
# Skipped: 00128.d93c580cbc23b080e501f3ea11dbaa5e (already has .txt extension)
# Skipped: 00129.084838d544f87b7ec7446ca4fc0052fa (already has .txt extension)
# Skipped: 00130.f1caab154ed658777c7c75bef652fba2 (already has .txt extension)
# Skipped: 00243.3bcfd197aa4187ca654e9b874d9c7833 (already has .txt extension)
# Skipped: 00244.6b536755550a406301a4dbd482341125 (already has .txt extension)
# Skipped: 00245.ad6a6e01bee8f1d84541fb127a86e31f (already has .txt extension)
# Skipped: 00246.fdaacadac7143848978ea0af07eed070 (already has .txt extension)
# Skipped: 00247.42534d5df0700cb2adf240556c539947 (already has .txt extension)
# Skipped: 00248.9599b06d2d2c08b57ff1de06316d66c0 (already has .txt extension)
# Skipped: 00249.b9183324a9726e8b6c8779045a921243 (already has .txt extension)
# Skipped: 00250.c7603b27a45284d12b49adf767b2b6fa (already has .txt extension)
# Skipped: cmds (already has .txt extension)

# %%
ham_train = []
ham_test = []

for o in ham_path:
    email_files = glob.glob(os.path.join(o, '*.txt'))
    print(f"Processing path: {o}")
    if len(email_files) > 1:
        print(f"Found {len(email_files)} email files.")
        train_set, test_set = train_test_split(email_files, test_size=0.2, random_state=42)
        ham_train.extend(train_set)
        ham_test.extend(test_set)

print(f"Total ham_train files: {len(ham_train)}")
print(f"Total ham_test files: {len(ham_test)}")
# Out:
# Processing path: C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\easy_ham
# Found 2502 email files.
# Processing path: C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\easy_ham_2
# Found 1401 email files.
# Processing path: C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\hard_ham
# Found 251 email files.
# Total ham_train files: 3321
# Total ham_test files: 833

# %%
if len(ham_train) > 0:
    ham_train_samples = []
    ham_test_samples = []

    for o in ham_path:
        email_files = glob.glob(os.path.join(o, '*.txt'))
        if len(email_files) > 1:
            print(f"Found {len(email_files)} email files in {o}")
            train_set, test_set = train_test_split(email_files, test_size=0.2, random_state=42)
            ham_train_samples.append(train_set)
            ham_test_samples.append(test_set)

    ham_train = np.concatenate(ham_train_samples)
    ham_test = np.concatenate(ham_test_samples)
    
    print(f"Ham train shape: {ham_train.shape}")
    print(f"Ham test shape: {ham_test.shape}")
else:
    print("Error: The dataset does not contain any samples.")
# Out:
# Found 2502 email files in C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\easy_ham
# Found 1401 email files in C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\easy_ham_2
# Found 251 email files in C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\hard_ham
# Ham train shape: (3321,)
# Ham test shape: (833,)

# %%
ham_train.shape, ham_test.shape
# Out:
# ((3321,), (833,))

# %%
for path in spam_path:
    files = os.listdir(path)
    for filename in files:
        if not filename.endswith('.txt'):
            new_filename = os.path.splitext(filename)[0] + '.txt'
            
            # Check if the .txt file already exists in the directory
            if os.path.exists(os.path.join(path, new_filename)):
                print(f"Skipped: {filename} (already has .txt extension)")
            else:
                os.rename(os.path.join(path, filename), os.path.join(path, new_filename))
                print(f"Renamed: {filename} -> {new_filename}")
# Out:
# Skipped: 00001.7848dde101aa985090474a91ec93fcf0 (already has .txt extension)
# Skipped: 00002.d94f1b97e48ed3b553b3508d116e6a09 (already has .txt extension)
# Skipped: 00003.2ee33bc6eacdb11f38d052c44819ba6c (already has .txt extension)
# Skipped: 00004.eac8de8d759b7e74154f142194282724 (already has .txt extension)
# Skipped: 00005.57696a39d7d84318ce497886896bf90d (already has .txt extension)
# Skipped: 00006.5ab5620d3d7c6c0db76234556a16f6c1 (already has .txt extension)
# Skipped: 00119.7bd666ac52f079fb3b5ff0be83b55286 (already has .txt extension)
# Skipped: 00120.58579af867ff9a702cff23e7b8818a59 (already has .txt extension)
# Skipped: 00121.bf18a63d6e7d40409f8b722036eadd82 (already has .txt extension)
# Skipped: 00122.98bcaad36eb81e75911371f841f28dfc (already has .txt extension)
# Skipped: 00123.a5ee0040ec9a30b3f32f61e547fa5f8f (already has .txt extension)
# Skipped: 00124.db848e36f1b4c2705cbc16ef33a302d4 (already has .txt extension)
# Skipped: 00125.120d27c936362896c00a3db9d3a4571e (already has .txt extension)
# Skipped: 00126.e98e1ba87a38e0cceeb55f3b86dbd4dd (already has .txt extension)
# Skipped: 00127.3500d109361b544b0937523adb763588 (already has .txt extension)
# Skipped: 00128.721b6b20d5834d490662e2ae8c5c0684 (already has .txt extension)
# Skipped: 00129.1080cea3a532759b015dc071d033749d (already has .txt extension)
# Skipped: 00130.c8128e89eff5b0e61aa864ebfd96afba (already has .txt extension)
# Skipped: 00131.d955acc659fb151479460f9dd2f87efe (already has .txt extension)
# Skipped: 00132.0ead3e293c6c41cbffb69670e8b85ae7 (already has .txt extension)
# Skipped: 00133.17dccf2499a4245b83890e0784c43499 (already has .txt extension)
# Skipped: 00134.9f41f4111a33dc1efca04de72e1a105a (already has .txt extension)
# Skipped: 00135.00e388e3b23df6278a8845047ca25160 (already has .txt extension)
# Skipped: 00136.faa39d8e816c70f23b4bb8758d8a74f0 (already has .txt extension)
# Skipped: 00137.09969121c8540730f1020b5a700b4c42 (already has .txt extension)
# Skipped: 00138.c15973a4d40bed4333079296be2522ca (already has .txt extension)
# Skipped: 00139.b2a205ac25d7d907cdfb3f865dbae1ae (already has .txt extension)
# Skipped: 00140.eba666846fa0a138a90aeef51a627022 (already has .txt extension)
# Skipped: 00141.c30e993ea9a98743b0a98733bdfba8c2 (already has .txt extension)
# Skipped: 00142.eddc7114a8566cbf83fa8210bf0d3603 (already has .txt extension)
# Skipped: 00143.13c0751d4b9f10098bb3ac85a435d884 (already has .txt extension)
# Skipped: 00144.4eeba2f228a8658e0d2e3a64764f4f31 (already has .txt extension)
# Skipped: 00145.0ec326fee0570953d684e40edd3fa7b8 (already has .txt extension)
# Skipped: 00146.e9b64856c0cd982a64f47c9ab9084287 (already has .txt extension)
# Skipped: 00147.1782d51354c31ea53db25ea927d5c51d (already has .txt extension)
# Skipped: 00148.21c30154aa358d903c10c5d8a3ef6ffd (already has .txt extension)
# Skipped: 00149.c07359393107925a86798dd72d6a56b3 (already has .txt extension)
# Skipped: 00150.f97c73fa56460a6afc6d9418ad76b5b5 (already has .txt extension)
# Skipped: 00151.34bbdbf089edc6f58080753a166a3cfc (already has .txt extension)
# Skipped: 00152.8ed8aaed94054e507af5b9c760dd7be6 (already has .txt extension)
# Skipped: 00153.6a5ffe584834ea334041ab958cadcadb (already has .txt extension)
# Skipped: 00154.b6c448ccff434e2dbe2c7c200a36aa31 (already has .txt extension)
# Skipped: 00155.1c37ce73590cc67186717a491ed0db5f (already has .txt extension)
# Skipped: 00193.c04ef77bc3dbaa5762760a6ea138df0e (already has .txt extension)
# Skipped: 00194.767c323b4ae7a4909397e42cbd0c56a4 (already has .txt extension)
# Skipped: 00195.0a543c2780491168160570bb6708af86 (already has .txt extension)
# Skipped: 00196.dd21040c7757d477c967ae71b537810e (already has .txt extension)
# Skipped: 00197.5a921df53d215a60d557c68754559e93 (already has .txt extension)
# Skipped: 00198.aad7df5b8be674a0ce09c8040ef53f1e (already has .txt extension)
# Skipped: 00199.9be6cec49c53210152780926cdeb59ff (already has .txt extension)
# Skipped: 00200.bacd4b2168049778b480367ca670254f (already has .txt extension)
# Skipped: 00201.00020fc9911604f6cae7ae0f598ad29d (already has .txt extension)
# Skipped: 00202.d5b52386f66bd36cd1508319c82cf671 (already has .txt extension)
# Skipped: 00203.3956f8506171ffd90a0060cafad4fdea (already has .txt extension)
# Skipped: 00204.a008813ddeb2d5febd1fc676c07e9760 (already has .txt extension)
# Skipped: 00205.312e72065386636132fa6c4a1fde871e (already has .txt extension)
# Skipped: 00206.0c8362d7e86ddcaf39829800ac40e2ca (already has .txt extension)
# Skipped: 00207.0b71ac81a360455c1514f5872564b1e1 (already has .txt extension)
# Skipped: 00208.369921416af87a0b70f133632131b184 (already has .txt extension)
# Skipped: 00209.5276f967533f2ce0209c1eff631a86ff (already has .txt extension)
# Skipped: 00210.050ffd105bd4e006771ee63cabc59978 (already has .txt extension)
# Skipped: 00211.d976c6049e8448e7c407c124b580e0ba (already has .txt extension)
# Skipped: 00212.a9947ad74a529a35d11538e1df60cd73 (already has .txt extension)
# Skipped: 00213.8c42a1c257aa30ff3b3ba668cca59408 (already has .txt extension)
# Skipped: 00214.1367039e50dc6b7adb0f2aa8aba83216 (already has .txt extension)
# Skipped: 00215.f571ecd203e8d39296419bffc47e4a6a (already has .txt extension)
# Skipped: 00216.89c1ede0b81fb09f7334f47a5183410a (already has .txt extension)
# Skipped: 00217.43b4ef3d9c56cf42be9c37b546a19e78 (already has .txt extension)
# Skipped: 00218.917ed95f5c90c1d9d15d2528b0bd1e79 (already has .txt extension)
# Skipped: 00219.eaf6c0ff67706c784f67f5c1225028a1 (already has .txt extension)
# Skipped: 00220.cf7d03e161582887dc589229e2896e26 (already has .txt extension)
# Skipped: 00221.c4dfeecf0cacc9469540337f5baf69db (already has .txt extension)
# Skipped: 00222.77293b7002c5749b9d31a99b2f4e0366 (already has .txt extension)
# Skipped: 00223.349b9b0748ee72bad60729ffaae2cc00 (already has .txt extension)
# Skipped: 00224.0654fe0af51e1dcefa0eb66eb932f55f (already has .txt extension)
# Skipped: 00225.b1ca16fa2be1be1d68f5e3bf2603f3cb (already has .txt extension)
# Skipped: 00226.e0e2704cde3bbd561a98042f4a3baf5f (already has .txt extension)
# Skipped: 00227.1171cc6d8c586141b4110a2abdccba00 (already has .txt extension)
# Skipped: 00228.cf58326ab05a757c7e759acc8d6b360d (already has .txt extension)
# Skipped: 00229.4c37dd3d98b8d6fb2694b6f83061ca5a (already has .txt extension)
# Skipped: 00027.b7b61e4624a29097cf55b578089c6110 (already has .txt extension)
# Skipped: 00028.60393e49c90f750226bee6381eb3e69d (already has .txt extension)
# Skipped: 00029.cc0c62b49c1df0ad08ae49a7e1904531 (already has .txt extension)
# Skipped: 00030.b360f27c098b3ab5cff96433e7963d4a (already has .txt extension)
# Skipped: 00031.e50cc5af8bd1131521b551713370a4b1 (already has .txt extension)
# Skipped: 00032.3b93a3c65e0a2454fc9646ce01363938 (already has .txt extension)
# Skipped: 00033.53ab3a0f8862eb0c12fa6eb3d04badbb (already has .txt extension)
# Skipped: 00034.cac95512308c52cfba33258e46feff97 (already has .txt extension)
# Skipped: 00035.bd7183c238b884a153ad4888fbee9bf6 (already has .txt extension)
# Skipped: 00036.5b5e714c8d5b1050a392e55c42070f2c (already has .txt extension)
# Skipped: 00037.c7f0ce13d4cad8202f3d1a02b5cc5a1d (already has .txt extension)
# Skipped: 00038.906d76babc3d78d6294c71b1b52d4d7f (already has .txt extension)
# Skipped: 00039.1295593cb1da98e80123f333def0b8dd (already has .txt extension)
# Skipped: 00040.d9570705b90532c2702859569bf4d01c (already has .txt extension)
# Skipped: 00041.1b8dedcc43e75c0f4cd5e0d12c4eea8b (already has .txt extension)
# Skipped: 00042.534ed9af47ca4349d84bc574a4306284 (already has .txt extension)
# Skipped: 00043.9331daf0bd865aa657cb02cbcd06173b (already has .txt extension)
# Skipped: 00044.9f8c4b9ae007c6ded3d57476082bf2b2 (already has .txt extension)
# Skipped: 00045.c1a84780700090224ce6ab0014b20183 (already has .txt extension)
# Skipped: 00046.96a19afe71cd6f1f14c96293557a49ff (already has .txt extension)
# Skipped: 00047.3c90d41f59137916d6b80e6f8e16ccba (already has .txt extension)
# Skipped: 00048.91474353d7616d0df44b0fb04e2899ff (already has .txt extension)
# Skipped: 00049.83a0ff17486ed3866aeed9f45f5b3389 (already has .txt extension)
# Skipped: 00050.bdb8b228ff67fd4a61f8b0c8e81240c9 (already has .txt extension)
# Skipped: 00051.8b17ce16ace4d5845e2299c0123e1f14 (already has .txt extension)
# Skipped: 00052.44ec0206d8bc46f371f73d15709fdeea (already has .txt extension)
# Skipped: 00053.6e5c80e892cad9c9e6b04abe49a9031e (already has .txt extension)
# Skipped: 00054.58b5d10599e5e7c98ce1498f2ba3e42c (already has .txt extension)
# Skipped: 00055.0b668beca14ab545bd39f17dbe20775c (already has .txt extension)
# Skipped: 00056.64a6ee24c0b7bf8bdba8340f0a3aafda (already has .txt extension)
# Skipped: 00057.01c83e8ad13d3f438c105ebc31808aa4 (already has .txt extension)
# Skipped: 00058.00878d47d9a07c1c6f9c5a8593db7f55 (already has .txt extension)
# Skipped: 00059.d7351d4fe66fb96d83ffb65b4a60b3cc (already has .txt extension)
# Skipped: 00060.639a625d0a724d7411e1d5e2e7cb2bc3 (already has .txt extension)
# Skipped: 00061.4b25d456df484b9f7e01c59983591def (already has .txt extension)
# Skipped: 00062.6a56c37b8db0cbfb57a99b32ad60b4d2 (already has .txt extension)
# Skipped: 00063.98dc120045d9b6c675c286524bf893ba (already has .txt extension)
# Skipped: 00064.839dfb3973ed439e19c1ca77cffdab3d (already has .txt extension)
# Skipped: 00065.9c8ae6822b427f2dbee5339d561a2888 (already has .txt extension)
# Skipped: 00066.af6bf70ea68b499585a72bdd7d6dd931 (already has .txt extension)
# Skipped: 00067.bf32243a9444bba9cba8582fef3d949e (already has .txt extension)
# Skipped: 00068.2999b3d00828ac3fbd6a7cd27a6c6321 (already has .txt extension)
# Skipped: 00069.27497d5d2f92837805b67e2bf31dfc71 (already has .txt extension)
# Skipped: 00070.598f33a87fd0df81c691f9109fc2378a (already has .txt extension)
# Skipped: 00071.11f438a86f442fd5a0772eb3908c12b4 (already has .txt extension)
# Skipped: 00072.eb147f0714c89bf35a0ab1852890555d (already has .txt extension)
# Skipped: 00073.fa47879bac3adc4b716130566ee0a2a6 (already has .txt extension)
# Skipped: 00074.f7cfc6a5142e788004e0cff70e3a36c0 (already has .txt extension)
# Skipped: 00075.f1c6bf042cf0ed13452e4a15929db8cd (already has .txt extension)
# Skipped: 00076.7d4561ac3b877bbd9fd64d1cb433cb54 (already has .txt extension)
# Skipped: 00077.6e13224e39fae4b94bcbe0f5ae9f4939 (already has .txt extension)
# Skipped: 00078.f318607d8f4699d51f456fea10838c5a (already has .txt extension)
# Skipped: 00079.7a1b9cd54acec8774ef833df17206630 (already has .txt extension)
# Skipped: 00080.2dda9e4297c6b66bff478c9d2d3756f1 (already has .txt extension)
# Skipped: 00081.4c7fbdca38b8def54e276e75ec56682e (already has .txt extension)
# Skipped: 00082.92b519133440f8e9e972978e7b82e25e (already has .txt extension)
# Skipped: 00083.1aead789d4b4c7022c51bc632e4f2445 (already has .txt extension)
# Skipped: 00084.eab3c85ce1b86d404296fc9d490d30dc (already has .txt extension)
# Skipped: 00085.ae2bf18f9dd33e3d80d11eda4c0be41d (already has .txt extension)
# Skipped: 00086.5ddcb4859b292c984d1db6aeade5ac04 (already has .txt extension)
# Skipped: 00087.c6bf843edd1028fd09bb46d88bf97699 (already has .txt extension)
# Skipped: 00088.34ca147ca21f4b3e966fe58bc054aaf6 (already has .txt extension)
# Skipped: 00089.1235261e1b2063edce03a18d06c11474 (already has .txt extension)
# Skipped: 00090.c82f6c8ce0db12e42a24fb2808974628 (already has .txt extension)
# Skipped: 00091.7b4331237cddd30e9fa27b99af25bf3c (already has .txt extension)
# Skipped: 00092.ba043c4ba04c2d06714e43caa42cc078 (already has .txt extension)
# Skipped: 00093.f0f5881aff74fafe925b36649298a0aa (already has .txt extension)
# Skipped: 00094.c3a37a3a866ce9583f51293a5e7b6f4e (already has .txt extension)
# Skipped: 00095.bee28d9bf506043611e140c673fe41f4 (already has .txt extension)
# Skipped: 00096.39bffb55f064f907234c6b3d82fc3b4c (already has .txt extension)
# Skipped: 00097.555911ef896c1f57a6232120685b01e7 (already has .txt extension)
# Skipped: 00098.842b0baaa0f03e439ec3a13ad5556e8c (already has .txt extension)
# Skipped: 00099.328fbebf5170afdd863e431d90ea90f5 (already has .txt extension)
# Skipped: 00100.f18596df33992ee2af3e79f71f092e69 (already has .txt extension)
# Skipped: 00101.1eefdf65cf34445662c1d308ef78d103 (already has .txt extension)
# Skipped: 00102.706dc065aaf3946565c4897163a16a33 (already has .txt extension)
# Skipped: 00103.3fb0c1ebdfc0eb5952bf0f57e635c270 (already has .txt extension)
# Skipped: 00104.67ea4a37ac02d37f4baa7631ba17a824 (already has .txt extension)
# Skipped: 00105.d8f25617befc5289aa4ed9602457050b (already has .txt extension)
# Skipped: 00106.09988f439b8547dc90efb1530c02329b (already has .txt extension)
# Skipped: 00107.49ebea517b7fe4f1bdf574dc3a125a70 (already has .txt extension)
# Skipped: 00108.813fc6306b631b5c58ecfc26caf3a8dc (already has .txt extension)
# Skipped: 00109.17824b03f1b16c199abc7f4d7c35e4eb (already has .txt extension)
# Skipped: 00110.6a98310639f4d8f87cabd99ce4155c77 (already has .txt extension)
# Skipped: 00111.029924c0533dcbc837512cce0792a18b (already has .txt extension)
# Skipped: 00112.e4952a7d270c78cd6bba9d4f6add13f2 (already has .txt extension)
# Skipped: 00113.0449844c534e41730bb7a0ab513580e9 (already has .txt extension)
# Skipped: 00114.68b089e3ca8128bb8d11f4f8bc592764 (already has .txt extension)
# Skipped: 00115.ea1a875067c4c0b710f5f4c951335723 (already has .txt extension)
# Skipped: 00116.8a15129846b680f8539fd703d8743b67 (already has .txt extension)
# Skipped: 00117.9f0ba9c35b1fe59307e32b7c2c0d4e61 (already has .txt extension)
# Skipped: 00118.141d803810acd9d4fc23db103dddfcd9 (already has .txt extension)
# Skipped: 00119.010f7f583440f966e427436c31738466 (already has .txt extension)
# Skipped: 00120.b6b2f20782980f83878f075f29d7c517 (already has .txt extension)
# Skipped: 00121.9fdf867ef2120e98641128801454aa72 (already has .txt extension)
# Skipped: 00122.4a2f67839c81141a1075745a66c907bb (already has .txt extension)
# ...
# Skipped: 01194.856467d118d99f873794faaf151a524b (already has .txt extension)
# Skipped: 01195.2e0668d1365c631aa09d21c813ce013f (already has .txt extension)
# Skipped: 01196.b4567843ec0343475dfcb5da7bd9c41f (already has .txt extension)
# Skipped: 01197.f88c038612948f3fa023ac83db2e2ce5 (already has .txt extension)
# Skipped: 01198.da6821edae608ba753c85e1a7436219b (already has .txt extension)
# Skipped: 01199.5a219c9b3e55a0136d8039fd74675570 (already has .txt extension)
# Skipped: 01200.6d388843b6ffefafaf7b3093ca28a740 (already has .txt extension)
# Skipped: 01201.471d379a63806032b2c3978838b83e61 (already has .txt extension)
# Skipped: 01202.4ec06d178a19d7972daf54bc3ba958ff (already has .txt extension)
# Skipped: 01203.f4c9144a594fb81ff323053fbd626a55 (already has .txt extension)
# Skipped: 01204.75323a3e0d38fe7a107bd0102daf6f26 (already has .txt extension)
# Skipped: 01205.47d139ac094945ae2630efb896dc4b43 (already has .txt extension)
# Skipped: 01206.b769233047fc696cc02ece9629190b42 (already has .txt extension)
# Skipped: 01207.c24e5ee957e060ad511b5d2b875ff222 (already has .txt extension)
# Skipped: 01208.6e10d44b4339eacb5db69d1afabae907 (already has .txt extension)
# Skipped: 01209.01df2f8f68a70062085ef787973f9ba0 (already has .txt extension)
# Skipped: 01210.3315bbc34ab0c51f53ee13e0dc6ccaec (already has .txt extension)
# Skipped: 01211.e9c2c3b1d544e8618d6f87c1871021e9 (already has .txt extension)
# Skipped: 01212.216774fff566f005d1ef404eda7925e2 (already has .txt extension)
# Skipped: 01213.7889eb65b4b7f2cde2a9bd3bb9f230dd (already has .txt extension)
# Skipped: 01214.973b4598b630a989967ff69b19f95d4a (already has .txt extension)
# Skipped: 01215.e879c633ccfba3b6dcf761d8ac0764c0 (already has .txt extension)
# Skipped: 01216.e293653cab0c486ba135cf8fbe6700fc (already has .txt extension)
# Skipped: 01217.d5a1734ec521c1bd55270eca3ab4acd8 (already has .txt extension)
# Skipped: 01218.4bb5c5746d9f19d8551437c242bfd79e (already has .txt extension)
# Skipped: 01219.db22b96619e848e2c9825ebb710897fe (already has .txt extension)
# Skipped: 01220.e399b9acc45a23ec853a9bb1d2a1a859 (already has .txt extension)
# Skipped: 01221.baf498fd213b8bc77b9dbfb13c1a6968 (already has .txt extension)
# Skipped: 01222.86831c8b346812d6526d6ddc7d3eb185 (already has .txt extension)
# Skipped: 01223.0321f73febcffd82fcf12b36cce2c6c9 (already has .txt extension)
# Skipped: 01224.5ec7daa5c1c540ce6be17e1afbef2a86 (already has .txt extension)
# Skipped: 01225.a07c90bc24b619d5e8b786675dc2d118 (already has .txt extension)
# Skipped: 01226.4aaf4e328bd55191a1c46bc374069048 (already has .txt extension)
# Skipped: 01227.04a4f94c7a73b29cb56bf38c7d526116 (already has .txt extension)
# Skipped: 01228.620009080894d11703ee91367628d633 (already has .txt extension)
# Skipped: 01229.bec63972cefbe62bb371ad659cd8563a (already has .txt extension)
# Skipped: 01230.0589bade8df0c343a49c6712f62dfca0 (already has .txt extension)
# Skipped: 01231.2a56f1f52d4da9f83870deb4b7e68acb (already has .txt extension)
# Skipped: 01232.2c1fbf4d9cb31dd039c1bbb078225b5a (already has .txt extension)
# Skipped: 01233.010677fced50f4aecb67fba70701bcf5 (already has .txt extension)
# Skipped: 01234.0bcd772346e2970c6246f40359cf4de5 (already has .txt extension)
# Skipped: 01235.2e8191ab7ddffa2290e04f9ce0422041 (already has .txt extension)
# Skipped: 01236.903d52340bf3ed1a328b039bcd94e1c9 (already has .txt extension)
# Skipped: 01237.245ac1766016b756a3ddb3b463cc9645 (already has .txt extension)
# Skipped: 01238.32c2cef2a001f81d237017d243bad8e4 (already has .txt extension)
# Skipped: 01239.5b4a6a500921ae2a53da84bc99d91414 (already has .txt extension)
# Skipped: 01240.7d6ae3682a3dd3fe457516b188eb105c (already has .txt extension)
# Skipped: 01241.0ea43b4457c3a0b85f7ab4d1bb4ac17e (already has .txt extension)
# Skipped: 01242.3743099b115c6a8a273d8eca34a9c738 (already has .txt extension)
# Skipped: 01243.0676aa0a6a02e5a0373d387b89af0e07 (already has .txt extension)
# Skipped: 01244.9ef966101737a6fc27d8965def288d70 (already has .txt extension)
# Skipped: 01245.ce437204a2dfc9109003491e7812fc7f (already has .txt extension)
# Skipped: 01282.9ae018dd0cf3c1f3345eb44074fd5635 (already has .txt extension)
# Skipped: 01283.e120df13e515b3cd7f0a14e21c9bf158 (already has .txt extension)
# Skipped: 01284.218c046acbc79f6f52c767fcb3fabbbc (already has .txt extension)
# Skipped: 01285.4bc4cabd8d963b1e33bb56aaaf191328 (already has .txt extension)
# Skipped: 01286.80a17353e03cab185cb52237b60359e4 (already has .txt extension)
# Skipped: 01287.45b0eefc02506c5c82e5ab4ffe2fc625 (already has .txt extension)
# Skipped: 01288.ffe370e3a92a1861533330da51edcb49 (already has .txt extension)
# Skipped: 01289.2f9168490b8c45e76af4935b4827f702 (already has .txt extension)
# Skipped: 01290.cc97aad0960efa7c8b76464b39d54bc9 (already has .txt extension)
# Skipped: 01291.4fee8a2f5fb6dce4e775b054282b6a71 (already has .txt extension)
# Skipped: 01292.3cfdacd938c6a4a7544581399e28e81c (already has .txt extension)
# Skipped: 01293.1073233e92a1fb8808e384cbc0d60e58 (already has .txt extension)
# Skipped: 01294.1b87da1a627d8b8f126839dad1220a1c (already has .txt extension)
# Skipped: 01295.7cea2d55caf3dfae98b350e67a431e35 (already has .txt extension)
# Skipped: 01296.34052422109f131a8b1fb59d1d42f899 (already has .txt extension)
# Skipped: 01297.6899dd73603e94dcefaba9970c3cfb69 (already has .txt extension)
# Skipped: 01298.3e410f64d440f9c883243bcc942b0f41 (already has .txt extension)
# Skipped: 01299.0eab794ad20a8b32dfa3d6e3fedc1b31 (already has .txt extension)
# Skipped: 01300.74283a1a03062473904cd6f9965df1d5 (already has .txt extension)
# Skipped: 01301.91269fd2b14a1fa0f183ca60953b99af (already has .txt extension)
# Skipped: 01302.6e23012bc215fef128943c14c7d2c83f (already has .txt extension)
# Skipped: 01303.59ad6322f5af1c3672849f504ad86fce (already has .txt extension)
# Skipped: 01304.114140cd4c51e9795559b974964aa043 (already has .txt extension)
# Skipped: 01305.2456653e0fbd780a77a3d25229109432 (already has .txt extension)
# Skipped: 01306.d37be8871ac501758c6854fbef9cbdd2 (already has .txt extension)
# Skipped: 01307.270e0fd3d0f0a14a592fcc47f3696e05 (already has .txt extension)
# Skipped: 01308.c46f1215ccd8cedf162e0cf308b94dcd (already has .txt extension)
# Skipped: 01309.4da3e5f7445fe71bdb9a145b3c704cc3 (already has .txt extension)
# Skipped: 01310.39e7167813c411d9163ceedcba3b3702 (already has .txt extension)
# Skipped: 01311.43bfe86df65d53c5f7ca2365dc12582b (already has .txt extension)
# Skipped: 01312.c19bb76293853f6c10871018cebbe8ca (already has .txt extension)
# Skipped: 01313.7deec268aedb7c5618e27bd73a803a60 (already has .txt extension)
# Skipped: 01314.12c8b5b91bc690f0f0d6fad595150ac6 (already has .txt extension)
# Skipped: 01315.88a113666f60469492624820111ee3be (already has .txt extension)
# Skipped: 01316.80287bffff0da77d7b22a538aefdbd01 (already has .txt extension)
# Skipped: 01317.2fb1c15091162a0a83cb7020e45e8de6 (already has .txt extension)
# Skipped: 01318.5ceb2b7a8b5780b006500266f5a508ca (already has .txt extension)
# Skipped: 01319.ec67d39c89f4a5865b730879685f3092 (already has .txt extension)
# Skipped: 01320.9d28c111c72720b5cd64a025591dbce5 (already has .txt extension)
# Skipped: 01321.f32dcf9a564da7e27f9fcad664cb0fe1 (already has .txt extension)
# Skipped: 01322.ff3e699f59f732ca886de5873eef313e (already has .txt extension)
# Skipped: 01323.043a9a503f711ebb76897fa1c352d7cd (already has .txt extension)
# Skipped: 01324.6ae300702ee69538834dccea9b774fef (already has .txt extension)
# Skipped: 01325.cf45b154c74e16a83def9f17383b5756 (already has .txt extension)
# Skipped: 01326.32e7912cae22a40e7b27f7d020de08fe (already has .txt extension)
# Skipped: 01327.7d7cb2b319318af27a2981701843f358 (already has .txt extension)
# Skipped: 01328.b23902de23cb3ca1f3334517282372b2 (already has .txt extension)
# Skipped: 01329.75ca6f174da63761de16480f22089dae (already has .txt extension)
# Skipped: 01330.dafb0dd3006f86f73f42b4e24266277c (already has .txt extension)
# Skipped: 01331.e35989787f99e9f234da42636eb43f22 (already has .txt extension)
# Skipped: 01332.f794e2c48ef6535153adde00b521ef6d (already has .txt extension)
# Skipped: 01333.1e5a572d1c326c109f613a9d2137acc8 (already has .txt extension)
# Skipped: 01334.24b7f4702e0da7e9d7a5f4d284adfc96 (already has .txt extension)
# Skipped: 01335.ca70ab7f2d1accef8b3cf646e3004ef8 (already has .txt extension)
# Skipped: 01336.cce700d418ddce6f5081cdcda625074f (already has .txt extension)
# Skipped: 01337.e490c19d9987a1532dd2e8f1a2e76fdc (already has .txt extension)
# Skipped: 01338.a67c3827402b4610bd2a6814cd8cd907 (already has .txt extension)
# Skipped: 01339.d94a16532a6f42497266dcc327a40163 (already has .txt extension)
# Skipped: 01340.0b77f53fb084eb948e07dc7ed2ab5c34 (already has .txt extension)
# Skipped: 01341.62703c6047c508d1d84bde0b7653b556 (already has .txt extension)
# Skipped: 01342.7f89acf56fb4398340a0b07481e3193f (already has .txt extension)
# Skipped: 01343.97e31a95126f0c6dc249a8e51489af10 (already has .txt extension)
# Skipped: 01344.43dbbbac0d006790dd696123d455f5b9 (already has .txt extension)
# Skipped: 01345.436954c32bbf82773e33853ac26ef881 (already has .txt extension)
# Skipped: 01346.fb942e99ad6211fe374675bc9ac639d5 (already has .txt extension)
# Skipped: 01347.e2cd456cd2d58601fec5a5b6323463e1 (already has .txt extension)
# Skipped: 01348.0ed90bb4a1ba1ea2309ffdbbce093753 (already has .txt extension)
# Skipped: 01349.71c7c224e68df0a19c1834065368c89f (already has .txt extension)
# Skipped: 01350.31d85a79d8c3b80069316daf56176820 (already has .txt extension)
# Skipped: 01351.e960056da1502c90d40d598cdf37f359 (already has .txt extension)
# Skipped: 01352.875dff8a1fd32766be05e136950add70 (already has .txt extension)
# Skipped: 01353.369f79f8f31f3b18bdb5d1006207b52e (already has .txt extension)
# Skipped: 01354.942feb599d3e244a238c28c9028d97fa (already has .txt extension)
# Skipped: 01355.a47c042a6e16456c5b49c18d5b3868cb (already has .txt extension)
# Skipped: 01356.8d996c0bc08a47a90611de2e8a829048 (already has .txt extension)
# Skipped: 01357.531b966b657f95f04a9037ea7100aa9f (already has .txt extension)
# Skipped: 01358.eb6c715f631ee3d22b135adb4dc4e67d (already has .txt extension)
# Skipped: 01359.deafa1d42658c6624c6809a446b7f369 (already has .txt extension)
# Skipped: 01360.5bf908ff3e674f31061afcb8a6c17a8d (already has .txt extension)
# Skipped: 01361.1b094e93a9a83d77859dcbf6637455d1 (already has .txt extension)
# Skipped: 01362.794d3043053407d8e0c075a9a71902bd (already has .txt extension)
# Skipped: 01363.85518bca7c7cb9f35e57f3adda762ac9 (already has .txt extension)
# Skipped: 01364.b89de202e8d843d54ab7988af8599571 (already has .txt extension)
# Skipped: 01365.d90d27bbb210dbdc63ed704b00161315 (already has .txt extension)
# Skipped: 01366.35ed342f7df33799c8ba619098b174c6 (already has .txt extension)
# Skipped: 01367.d681bf8f9823da056b82da169d2d1715 (already has .txt extension)
# Skipped: 01368.0fcb4c25d287618ec7cdf84822d3d405 (already has .txt extension)
# Skipped: 01369.8ea24235c6c50337d9dcd234e61a5132 (already has .txt extension)
# Skipped: 01370.38a1c6fbbad5804a9978112005535de1 (already has .txt extension)
# Skipped: 01371.fd75cda79a01e9b7d11af36936463c0d (already has .txt extension)
# Skipped: 01372.5d236077d94148a0ca71751f8f0a2e58 (already has .txt extension)
# Skipped: 01373.c8c124454ee4d1b775ef7a436cede7c1 (already has .txt extension)
# Skipped: 01374.b902d53d7f737be700d6de60a42122d9 (already has .txt extension)
# Skipped: 01375.b1a9c15e903adbc27bd2b5c033e1d29c (already has .txt extension)
# Skipped: 01376.73e738e4cd8121ce3dfb42d190b193c9 (already has .txt extension)
# Skipped: 01377.17adb34fc692245ce301d3db0a3e80c8 (already has .txt extension)
# Skipped: 01378.73df5252cb71f89c885ad49b6ae5fa82 (already has .txt extension)
# Skipped: 01379.0d39498608cd170bbbc8cd33ffd18e35 (already has .txt extension)
# Skipped: 01380.fa9b4e89ba485def2921e01ae9fb7671 (already has .txt extension)
# Skipped: 01381.7f1f9f4b8ea24fee6b87dc1172177eaf (already has .txt extension)
# Skipped: 01382.37400f7a1f36cd45165c2a72a9ec8baa (already has .txt extension)
# Skipped: 01383.a4e83a74006864de20f76d0193908a56 (already has .txt extension)
# Skipped: 01384.e23f94030a4393f0825eacd9de99eb31 (already has .txt extension)
# Skipped: 01385.af7a1a172a6cd00ad09dc6adecb14cee (already has .txt extension)
# Skipped: 01386.9398d616dfc3d67fb10e95d911768b39 (already has .txt extension)
# Skipped: 01387.84a80f5699b026b15455e803a471b88e (already has .txt extension)
# Skipped: 01388.dba0966da5886e99fab13981da6c3834 (already has .txt extension)
# Skipped: 01389.35f4d2a5f47c4b434434b3ca8dc5a924 (already has .txt extension)
# Skipped: 01390.271af498812d2f73c8c198fd4fda905e (already has .txt extension)
# Skipped: 01391.d84700fa88ef00525b05a2d9c64fa654 (already has .txt extension)
# Skipped: 01392.891b7eeda19704fc8a990e56e0b52f89 (already has .txt extension)
# Skipped: 01393.e7d7a58f2c561c6f71fe95c64a7f5f35 (already has .txt extension)
# Skipped: 01394.a76cc347fac514441bef43e7a599fb55 (already has .txt extension)
# Skipped: 01395.cb33d1d72f42e4ab9268729917bf428b (already has .txt extension)
# Skipped: 01396.e80a10644810bc2ae3c1b58c5fd38dfa (already has .txt extension)
# Skipped: 01397.f75f0dd0dd923faefa3e9cc5ecb8c906 (already has .txt extension)
# Skipped: 01398.8ca7045aae4184d56e8509dc5ad6d979 (already has .txt extension)
# Skipped: 01399.2319643317e2c5193d574e40a71809c2 (already has .txt extension)
# Skipped: 01400.b444b69845db2fa0a4693ca04e6ac5c5 (already has .txt extension)
# Skipped: cmds (already has .txt extension)

# %%
spam_train = []
spam_test = []

for o in spam_path:
    email_files = glob.glob(os.path.join(o, '*.txt'))
    print(f"Processing path: {o}")
    if len(email_files) > 1:
        print(f"Found {len(email_files)} email files.")
        train_set, test_set = train_test_split(email_files, test_size=0.2, random_state=42)
        spam_train.extend(train_set)
        spam_test.extend(test_set)

print(f"Total spam_train files: {len(spam_train)}")
print(f"Total spam_test files: {len(spam_test)}")
# Out:
# Processing path: C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\spam
# Found 501 email files.
# Processing path: C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\spam_2
# Found 1397 email files.
# Total spam_train files: 1517
# Total spam_test files: 381

# %%
if len(spam_train) > 0:
    spam_train_samples = []
    spam_test_samples = []

    for o in spam_path:
        email_files = glob.glob(os.path.join(o, '*.txt'))
        if len(email_files) > 1:
            print(f"Found {len(email_files)} email files in {o}")
            train_set, test_set = train_test_split(email_files, test_size=0.2, random_state=42)
            spam_train_samples.append(train_set)
            spam_test_samples.append(test_set)

    spam_train = np.concatenate(spam_train_samples)
    spam_test = np.concatenate(spam_test_samples)
    
    print(f"Spam train shape: {spam_train.shape}")
    print(f"Spam test shape: {spam_test.shape}")
else:
    print("Error: The dataset does not contain any samples.")
# Out:
# Found 501 email files in C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\spam
# Found 1397 email files in C:\Users\BROOKLYNBOSS\Desktop\PROJECT\data\spam data\spam_2
# Spam train shape: (1517,)
# Spam test shape: (381,)

# %%
spam_train.shape, spam_test.shape
# Out:
# ((1517,), (381,))

# %%
ham_train_label = [0]*ham_train.shape[0]
spam_train_label = [1]*spam_train.shape[0]
x_train = np.concatenate((ham_train,spam_train))
y_train = np.concatenate((ham_train_label,spam_train_label))

# %%
ham_test_label = [0]*ham_test.shape[0]
spam_test_label = [1]*spam_test.shape[0]
x_test = np.concatenate((ham_test,spam_test))
y_test = np.concatenate((ham_test_label,spam_test_label))

# %%
train_shuffle_index = np.random.permutation(np.arange(0,x_train.shape[0]))
test_shuffle_index = np.random.permutation(np.arange(0,x_test.shape[0]))

# %%
x_train = x_train[train_shuffle_index]
y_train = y_train[train_shuffle_index]

# %%
x_test = x_test[test_shuffle_index]
y_test = y_test[test_shuffle_index]

# %%
x_train = get_email_content_bulk(x_train)
x_test = get_email_content_bulk(x_test)

# %%
def remove_null(datas,labels):
    not_null_idx = [i for i,o in enumerate(datas) if o is not None]
    return np.array(datas)[not_null_idx],np.array(labels)[not_null_idx]

# %%
x_train,y_train = remove_null(x_train,y_train)
x_test,y_test = remove_null(x_test,y_test)

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Process sentence

# %% [markdown]
# ### Cleaning Up (Part 1)

# %%
import re
import string
from nltk.tokenize import word_tokenize

# %%
def remove_hyperlink(word):
    return  re.sub(r"http\S+", "", word)

# %%
def to_lower(word):
    result = word.lower()
    return result

# %%
def remove_number(word):
    result = re.sub(r'\d+', '', word)
    return result

# %%
def remove_punctuation(word):
    result = word.translate(str.maketrans(dict.fromkeys(string.punctuation)))
    return result

# %%
def remove_whitespace(word):
    result = word.strip()
    return result

# %%
def replace_newline(word):
    return word.replace('\n','')

# %%
def clean_up_pipeline(sentence):
    cleaning_utils = [remove_hyperlink,
                      replace_newline,
                      to_lower,
                      remove_number,
                      remove_punctuation,remove_whitespace]
    for o in cleaning_utils:
        sentence = o(sentence)
    return sentence

# %%
x_train = [clean_up_pipeline(o) for o in x_train]
x_test = [clean_up_pipeline(o) for o in x_test]

# %% [markdown]
# ### Cleaning Up (Part 2)

# %%
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\BROOKLYNBOSS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\BROOKLYNBOSS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
# Tokenization are taking slightly longer to process

x_train = [word_tokenize(o) for o in x_train]
x_test = [word_tokenize(o) for o in x_test]

# %%
def remove_stop_words(words):
    result = [i for i in words if i not in ENGLISH_STOP_WORDS]
    return result

# %%
def word_stemmer(words):
    return [stemmer.stem(o) for o in words]

# %%
def word_lemmatizer(words):
    return [lemmatizer.lemmatize(o) for o in words]

# %%
def clean_token_pipeline(words):
    cleaning_utils = [remove_stop_words,word_lemmatizer]
    for o in cleaning_utils:
        words = o(words)
    return words

# %%
x_train = [clean_token_pipeline(o) for o in x_train]
x_test = [clean_token_pipeline(o) for o in x_test]

# %%
x_train = [" ".join(o) for o in x_train]
x_test = [" ".join(o) for o in x_test]

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# %%
def plot_wordcloud(text, mask=None, max_words=200, max_font_size=100, figure_size=(24.0,16.0),
                   title = None, title_size=40, image_color=False):
    stopwords = set(STOPWORDS)
    more_stopwords = {'one', 'br', 'Po', 'th', 'sayi', 'fo', 'Unknown'}
    stopwords = stopwords.union(more_stopwords)

    wordcloud = WordCloud(background_color='black',
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = max_font_size,
                    random_state = 42,
                    width=800,
                    height=400,
                    mask = mask)
    wordcloud.generate(str(text))

    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'black',
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()

# %%
spam_train_index = [i for i,o in enumerate(y_train) if o == 1]
non_spam_train_index = [i for i,o in enumerate(y_train) if o == 0]

# %%
spam_email = np.array(x_train)[spam_train_index]
non_spam_email = np.array(x_train)[non_spam_train_index]

# %%
plot_wordcloud(spam_email,title = 'Spam Email')

# %%
plot_wordcloud(non_spam_email,title="Non Spam Email")

# %% [markdown]
# # Visualizing using bar chart

# %%
from plotly.subplots import make_subplots
import IPython
import pandas as pd
import plotly.graph_objs as go
from collections import defaultdict
import plotly.offline as py

def configure_plotly_browser_state():
    display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
    '''))

def generate_ngrams(text, n_gram=1):
    token = [token for token in text.lower().split(" ") if token != "" if token not in STOPWORDS]
    ngrams = zip(*[token[i:] for i in range(n_gram)])
    return [" ".join(ngram) for ngram in ngrams]

def horizontal_bar_chart(df, color):
    trace = go.Bar(
        y=df["word"].values[::-1],
        x=df["wordcount"].values[::-1],
        showlegend=False,
        orientation='h',
        marker=dict(
            color=color,
        ),
    )
    return trace

def visualize_in_bar_chart(word_count=1):
    ## Get the bar chart from sincere questions ##
    freq_dict = defaultdict(int)
    for sent in non_spam_email:
        for word in generate_ngrams(sent, word_count):
            freq_dict[word] += 1
    fd_sorted = pd.DataFrame(sorted(freq_dict.items(), key=lambda x: x[1])[::-1])
    fd_sorted.columns = ["word", "wordcount"]
    trace0 = horizontal_bar_chart(fd_sorted.head(20), 'orange')

    ## Get the bar chart from insincere questions ##
    freq_dict = defaultdict(int)
    for sent in spam_email:
        for word in generate_ngrams(sent, word_count):
            freq_dict[word] += 1
    fd_sorted = pd.DataFrame(sorted(freq_dict.items(), key=lambda x: x[1])[::-1])
    fd_sorted.columns = ["word", "wordcount"]
    trace1 = horizontal_bar_chart(fd_sorted.head(20), 'orange')

    # Creating two subplots
    fig = make_subplots(rows=1, cols=2, vertical_spacing=0.04,
                        subplot_titles=["Frequent words of non spam email",
                                        "Frequent words of spam email"])
    fig.append_trace(trace0, 1, 1)
    fig.append_trace(trace1, 1, 2)
    fig['layout'].update(height=600, width=800, paper_bgcolor='rgb(233,233,233)', title="Word Count Plots")
    py.iplot(fig, filename='word-plots')
    configure_plotly_browser_state()

visualize_in_bar_chart(2)
# Out:
# <div>                            <div id="05badb03-231e-4e0e-88f2-693af2ac608e" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05badb03-231e-4e0e-88f2-693af2ac608e")) {                    Plotly.newPlot(                        "05badb03-231e-4e0e-88f2-693af2ac608e",                        [{"marker":{"color":"orange"},"orientation":"h","showlegend":false,"x":[158,167,170,170,186,188,193,330,389,389,465,473,476,476,487,495,498,501,505,509],"xaxis":"x","y":["dont know","original message","sponsored bythinkgeekwelcome","bythinkgeekwelcome geek","yahoo group","red hat","use perl","list rpmlistfreshrpmsnet","sfnet email","email sponsored","iluglinuxie unsubscription","group iluglinuxie","unsubscription informationlist","informationlist maintainer","url date","maintainer listmasterlinuxie","irish linux","mailing list","user group","linux user"],"yaxis":"y","type":"bar"},{"marker":{"color":"orange"},"orientation":"h","showlegend":false,"x":[79,81,89,92,93,96,105,113,115,122,122,136,149,163,270,270,270,270,270,270],"xaxis":"x2","y":["ragga dagga","list reply","dont want","web site","marshall island","bulk email","order report","tr tr","kingdom enenkio","send email","united state","credit card","mailing list","tr td","email address","faceverdana geneva","geneva arial","arial helvetica","helvetica sansseriffont","sansseriffont colorfont"],"yaxis":"y2","type":"bar"}],                        {"annotations":[{"font":{"size":16},"showarrow":false,"text":"Frequent words of non spam email","x":0.225,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"},{"font":{"size":16},"showarrow":false,"text":"Frequent words of spam email","x":0.775,"xanchor":"center","xref":"paper","y":1.0,"yanchor":"bottom","yref":"paper"}],"height":600,"paper_bgcolor":"rgb(233,233,233)","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks" ...
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>

# %% [markdown]
# ## Target Distribution

# %%
from plotly import tools
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
spam_train_index = [i for i,o in enumerate(y_train) if o == 1]
non_spam_train_index = [i for i,o in enumerate(y_train) if o == 0]

# %%
configure_plotly_browser_state()

spam_size = len(spam_train_index)
non_spam_size = len(non_spam_train_index)
total_train_size = spam_size + non_spam_size

trace = go.Bar(
    x=["Spam","Non Spam"],
    y=[spam_size, non_spam_size],
    marker=dict(
        color=[spam_size, non_spam_size],
        colorscale = 'Picnic',
        reversescale = True
    ),
)

layout = go.Layout(
    title='Target Count for Train Data',
    font=dict(size=18)
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="TargetCount")

## target distribution ##
labels = (np.array(["Spam", "Non Spam"]))
sizes = (np.array(([spam_size,non_spam_size]))/total_train_size*100)

trace = go.Pie(labels=labels, values=sizes)
layout = go.Layout(
    title='Train Data distribution',
    font=dict(size=18),
    width=600,
    height=600,
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="usertype")
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>                            <div id="8d1eb064-73c7-4eb4-828d-58b983214ab3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d1eb064-73c7-4eb4-828d-58b983214ab3")) {                    Plotly.newPlot(                        "8d1eb064-73c7-4eb4-828d-58b983214ab3",                        [{"marker":{"color":[843,3228],"colorscale":[[0.0,"rgb(0,0,255)"],[0.1,"rgb(51,153,255)"],[0.2,"rgb(102,204,255)"],[0.3,"rgb(153,204,255)"],[0.4,"rgb(204,204,255)"],[0.5,"rgb(255,255,255)"],[0.6,"rgb(255,204,255)"],[0.7,"rgb(255,153,255)"],[0.8,"rgb(255,102,204)"],[0.9,"rgb(255,102,102)"],[1.0,"rgb(255,0,0)"]],"reversescale":true},"x":["Spam","Non Spam"],"y":[843,3228],"type":"bar"}],                        {"font":{"size":18},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker": ...
# <div>                            <div id="b5803031-0006-47ee-8d80-1d98a657871f" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b5803031-0006-47ee-8d80-1d98a657871f")) {                    Plotly.newPlot(                        "b5803031-0006-47ee-8d80-1d98a657871f",                        [{"labels":["Spam","Non Spam"],"values":[20.70744288872513,79.29255711127487],"type":"pie"}],                        {"font":{"size":18},"height":600,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"colorba ...
#
# var gd = document.getElementById('b5803031-0006-47ee-8d80-1d98a657871f');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'non

# %%
configure_plotly_browser_state()

spam_test_index = [i for i,o in enumerate(y_test) if o == 1]
non_spam_test_index = [i for i,o in enumerate(y_test) if o == 0]

spam_size = len(spam_test_index)
non_spam_size = len(non_spam_test_index)
total_test_size = spam_size + non_spam_size

trace = go.Bar(
    x=["Spam","Non Spam"],
    y=[spam_size, non_spam_size],
    marker=dict(
        color=[spam_size, non_spam_size],
        colorscale = 'Picnic',
        reversescale = True
    ),
)

layout = go.Layout(
    title='Target Count for Test Data',
    font=dict(size=18)
)

data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="TargetCount")

## target distribution ##
labels = (np.array(["Spam", "Non Spam"]))
sizes = (np.array(([spam_size,non_spam_size]))/total_train_size*100)

trace = go.Pie(labels=labels, values=sizes)
layout = go.Layout(
    title='Test Data Distribution',
    font=dict(size=18),
    width=600,
    height=600,
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="usertype")
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>                            <div id="e519635a-db6f-4ba3-ac62-1e63eac5b490" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e519635a-db6f-4ba3-ac62-1e63eac5b490")) {                    Plotly.newPlot(                        "e519635a-db6f-4ba3-ac62-1e63eac5b490",                        [{"marker":{"color":[202,804],"colorscale":[[0.0,"rgb(0,0,255)"],[0.1,"rgb(51,153,255)"],[0.2,"rgb(102,204,255)"],[0.3,"rgb(153,204,255)"],[0.4,"rgb(204,204,255)"],[0.5,"rgb(255,255,255)"],[0.6,"rgb(255,204,255)"],[0.7,"rgb(255,153,255)"],[0.8,"rgb(255,102,204)"],[0.9,"rgb(255,102,102)"],[1.0,"rgb(255,0,0)"]],"reversescale":true},"x":["Spam","Non Spam"],"y":[202,804],"type":"bar"}],                        {"font":{"size":18},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{" ...
# <div>                            <div id="55896772-6134-45e8-a48b-39e43b17d0f6" class="plotly-graph-div" style="height:600px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55896772-6134-45e8-a48b-39e43b17d0f6")) {                    Plotly.newPlot(                        "55896772-6134-45e8-a48b-39e43b17d0f6",                        [{"labels":["Spam","Non Spam"],"values":[4.9619258167526406,19.749447310243184],"type":"pie"}],                        {"font":{"size":18},"height":600,"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"color ...
#
# var gd = document.getElementById('55896772-6134-45e8-a48b-39e43b17d0f6');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'no

# %% [markdown]
# # Feature Extraction

# %% [markdown]
# Using either TfidVectorizer of CountVectorizer

# %% [markdown]
# ## TfidVectorizer

# %%
x_train = [o.split(" ") for o in x_train]
x_test = [o.split(" ") for o in x_test]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()
raw_sentences = [' '.join(o) for o in x_train]
vectorizer.fit(raw_sentences)
# Out:
# TfidfVectorizer()

# %%
def convert_to_feature(raw_tokenize_data):
    raw_sentences = [' '.join(o) for o in raw_tokenize_data]
    return vectorizer.transform(raw_sentences)

# %%
x_train_features = convert_to_feature(x_train)
x_test_features = convert_to_feature(x_test)

# %% [markdown]
# ## CountVectorizer

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vectorizer = CountVectorizer()
raw_sentences = [' '.join(o) for o in x_train]
vectorizer.fit(raw_sentences)
# Out:
# CountVectorizer()

# %%
x_train_features = convert_to_feature(x_train)
x_test_features = convert_to_feature(x_test)

# %% [markdown]
# ## Training classifiers

# %% [markdown]
# ## Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression

# %%
clf = GaussianNB()

# %%
batch_size = 1000
for i in range(0, len(x_train), batch_size):
    x_batch = x_train_features[i:i + batch_size]
    y_batch = y_train[i:i + batch_size]
    clf.fit(x_batch.toarray(), y_batch)

# %%
# Compute the scores on the training data
train_score = clf.score(x_test_features.toarray(), y_test)
print("NB accuracy:", train_score)
# Out:
# NB accuracy: 0.820079522862823

# %%
# batch_size = 1000
# for i in range(0, len(x_train), batch_size):
#     x_batch = x_train_features[i:i + batch_size]
#     y_batch = y_train[i:i + batch_size]
#     clf.fit(x_batch.toarray(), y_batch)
#     clf.score(x_test_features.toarray(), y_test)

# Compute the scores on the training data
# train_score = clf.score(x_train_features.toarray(), y_train)
# print("Training Score:", train_score)

# %% [markdown]
# ## SVM

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, confusion_matrix

# Creating a LinearSVC classifier with increased max_iter
svm_classifier = LinearSVC(max_iter=10000)  
svm_classifier.fit(x_train_features, y_train)
svm_predictions = svm_classifier.predict(x_test_features)
accuracy = accuracy_score(y_test, svm_predictions)
print("SVM Accuracy:", accuracy)
# Out:
# SVM Accuracy: 0.9582504970178927

# %% [markdown]
# ## Error Analysis

# %% [markdown]
# ### Gaussian NB

# %%
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score

y_predict = clf.predict(x_test_features.toarray())
conf_matrix = confusion_matrix(y_test, y_predict)
tn, fp, fn, tp = conf_matrix.ravel()

precision = 100 * precision_score(y_test, y_predict)
recall = 100 * recall_score(y_test, y_predict)

print("NB Confusion Matrix:")
print(conf_matrix)
print("True Negatives:", tn)
print("False Positives:", fp)
print("False Negatives:", fn)
print("True Positives:", tp)
print("Precision: {:.2f}%".format(precision))
print("Recall: {:.2f}%".format(recall))
# Out:
# NB Confusion Matrix:
# [[801   3]
#  [178  24]]
# True Negatives: 801
# False Positives: 3
# False Negatives: 178
# True Positives: 24
# Precision: 88.89%
# Recall: 11.88%

# %% [markdown]
# ### Plot NB confusion matrix

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import itertools

# %%
conf_matrix = confusion_matrix(y_test,y_predict)

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(conf_matrix, classes=['Non Spam','Spam'], normalize=False,
                      title='NB Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[801   3]
#  [178  24]]

# %% [markdown]
# ## SVM ERROR ANALYSIS

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score

svm_predictions = svm_classifier.predict(x_test_features)
svm_conf_matrix = confusion_matrix(y_test, svm_predictions)
svm_tn, svm_fp, svm_fn, svm_tp = svm_conf_matrix.ravel()

svm_precision = 100 * precision_score(y_test, svm_predictions)
svm_recall = 100 * recall_score(y_test, svm_predictions)

print("SVM Confusion Matrix:")
print(svm_conf_matrix)
print("SVM True Negatives:", svm_tn)
print("SVM False Positives:", svm_fp)
print("SVM False Negatives:", svm_fn)
print("SVM True Positives:", svm_tp)
print("SVM Precision: {:.2f}%".format(svm_precision))
print("SVM Recall: {:.2f}%".format(svm_recall))
# Out:
# SVM Confusion Matrix:
# [[783  21]
#  [ 21 181]]
# SVM True Negatives: 783
# SVM False Positives: 21
# SVM False Negatives: 21
# SVM True Positives: 181
# SVM Precision: 89.60%
# SVM Recall: 89.60%

# %% [markdown]
# ##  SVM CONFUSION MATRIX

# %%
# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(svm_conf_matrix, classes=['Non Spam','Spam'], normalize=False,
                      title='SVM Confusion matrix')
# Out:
# Confusion matrix, without normalization
# [[783  21]
#  [ 21 181]]
